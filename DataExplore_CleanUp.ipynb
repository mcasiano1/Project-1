# %%
# Dependencies
import pandas as pd
import json
import numpy as np

# %%
# The path to our CSV file
csv_path = "Resources/country_vaccinations.csv"

# Read our COVID data into pandas
covid_df = pd.read_csv(csv_path)
covid_df.head()
# Out:
#    country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Algeria      DZA  1/29/2021                 0.0                NaN
# 1  Algeria      DZA  1/30/2021                30.0                NaN
# 2  Andorra      AND  1/25/2021               576.0              576.0
# 3  Andorra      AND  1/26/2021                 NaN                NaN
# 4  Andorra      AND  1/27/2021                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                    30.0                30.0
# 2                      NaN                     NaN                 NaN
# 3                      NaN                     NaN                66.0
# 4                      NaN                     NaN                66.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                            0.00                            NaN
# 1                            0.00                            NaN
# 2                            0.75                           0.75
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                             1.0
# 2                                  NaN                             NaN
# 3                                  NaN                           854.0
# 4                                  NaN                           854.0
#
#           vaccines            source_name  \
# 0        Sputnik V     Ministry of Health
# 1        Sputnik V     Ministry of Health
# 2  Pfizer/BioNTech  Government of Andorra
# 3  Pfizer/BioNTech  Government of Andorra
# 4  Pfizer/BioNTech  Government of Andorra
#
#                                       source_website
# 0  https://www.aps.dz/regions/116777-blida-covid-...
# 1  https://www.aps.dz/regions/116777-blida-covid-...
# 2  https://www.govern.ad/comunicats/item/12379-se...
# 3  https://www.govern.ad/comunicats/item/12379-se...
# 4  https://www.govern.ad/comunicats/item/12379-se...

# %%
#Q1:  Total number of people fully vaccinated by country and ratios-daily
#DF:  Country, Code, Date, People Fully Vaccinated, People Fully Vac/Hundred, add vaccine and source name
#CleanUp:  Remove ".0" from values, replace NaN with "0", delete "source_website" column

#Dict: Total number of people fully vaccinated - this is the number of people that received the entire set of immunization 
#according to the immunization scheme (typically 2); at a certain moment in time, there might be a certain number of people that received one vaccine and another number (smaller) of people that received all vaccines in the scheme;
#Total number of people fully vaccinated per hundred - ratio (in percent) between population fully immunized and total population up to the date in the country;
#Show covid_count() as part of understanding the data structure.  Show count and describe.
#Graph Type:  Bar Chart

covid_df.count()
# Out:
# country                                2468
# iso_code                               2235
# date                                   2468
# total_vaccinations                     1617
# people_vaccinated                      1340
# people_fully_vaccinated                 792
# daily_vaccinations_raw                 1327
# daily_vaccinations                     2371
# total_vaccinations_per_hundred         1617
# people_vaccinated_per_hundred          1340
# people_fully_vaccinated_per_hundred     792
# daily_vaccinations_per_million         2371
# vaccines                               2468
# source_name                            2468
# source_website                         2468
# dtype: int64

# %%
#Q2: Which vaccines and mixes are being distributed most /least. 
#DF: 
#Graph Type: Bar

# %%
#Create a new csv file (cleaned) to import into analysis workbook
